# %%
#importing libraries and modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Dataset
wine_data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Display total no. of rows and columns
print("The number of Rows in dataset " + str(wine_data.shape[0]))
print("The number of Columns in dataset " + str(wine_data.shape[1]))
# Out:
# The number of Rows in dataset 1599
# The number of Columns in dataset 12

# %%
# Display top 5 rows of the dataset. 
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Display bottom 5 rows of the dataset. 
wine_data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
# Printing columns name of the given dataset
wine_data.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# KEY INFORMATION BY ANALYSING FROM ABOVE DATASET-
#
# There are total 1599 entries(rows) with 12 columns with integer64 and float64 datatypes of variables.
#
# Only 'Quality' remains in int64 while the rest of the data is in float64.
#
# The second column give us an idea about how big the dataset and how many non-null values are there for each field.
# The total memory usage is 150kb.

# %%
wine_data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# As there is integer64 and float64 datatypes of variables.Only Quality remains in int64 while the rest of the data is in float64.

# %%
 # returns the total number of unique values for each variable.
wine_data.nunique().to_frame("Total No. of Unique Values in each column")
# Out:
#                       Total No. of Unique Values in each column
# fixed acidity                                                96
# volatile acidity                                            143
# citric acid                                                  80
# residual sugar                                               91
# chlorides                                                   153
# free sulfur dioxide                                          60
# total sulfur dioxide                                        144
# density                                                     436
# pH                                                           89
# sulphates                                                    96
# alcohol                                                      65
# quality                                                       6

# %% [markdown]
# This dataset contains categorical data .Here,Quality is our target variable and contains categorical information.

# %%
#checking the value count for each columns

for col in wine_data.columns:   
    print('-' * 20 + col + '-' * 20 , end=' - ')
    display(wine_data[col].value_counts())
# Out:
# --------------------fixed acidity-------------------- -
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
# --------------------volatile acidity-------------------- -
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
# --------------------citric acid-------------------- -
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
# --------------------residual sugar-------------------- -
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# ...

# %%
#summarizes the count, mean, standard deviation, min, and max for numeric variables.
wine_data.describe(include = 'all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# All the columns has same count as 1599 which means there is no null values in the dataset.
#
# The Mean is greater than the Median (50th percentile ) in all the columns, this shows that the data is right sided skewed.
#
# There is a large difference between the 75% (quantile 3) and max values in 'residual sugar','free sulfurdioxide' and 'total sulfur dioxide',which indicates there is skewness/outliers in the data.
#
# The std data in 'free sulfurdioxide' and 'total sulfur dioxide' are highly spreaded that means the possibility of outliers are more.

# %%
wine_data.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.360000          0.884500     0.171000        2.635000
# 4             7.779245          0.693962     0.174151        2.694340
# 5             8.167254          0.577041     0.243686        2.528855
# 6             8.347179          0.497484     0.273824        2.477194
# 7             8.872362          0.403920     0.375176        2.720603
# 8             8.566667          0.423333     0.391111        2.577778
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.122500            11.000000             24.900000  0.997464
# 4         0.090679            12.264151             36.245283  0.996542
# 5         0.092736            16.983847             56.513950  0.997104
# 6         0.084956            15.711599             40.869906  0.996615
# 7         0.076588            14.045226             35.020101  0.996104
# ...

# %%
# Display the Missing Values
wine_data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#graphical representaion of null values
sns.heatmap(wine_data.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='quality',data=wine_data,kind = 'count')

# %%
plt.bar(wine_data['quality'],wine_data['fixed acidity'])
plt.xlabel('Quality')
plt.ylabel('Fixed acidity')
plt.show()

# %% [markdown]
# From this bar plot we can observe that as the Fixed acidity increses the Quality of the wine increases

# %%
plt.bar(wine_data['quality'],wine_data['volatile acidity'])
plt.xlabel('Quality')
plt.ylabel('Volatile acidity')
plt.show()

# %% [markdown]
# From this bar plot we can analyse as the volatile acidity increases the quality of the wine decreses.

# %%
plt.bar(wine_data['quality'],wine_data['residual sugar'])
plt.xlabel('Quality')
plt.ylabel('Residual sugar')
plt.show()

# %% [markdown]
# As the quality of sugar is less, the quality of the wine becomes bitter

# %%
plt.bar(wine_data['quality'],wine_data['chlorides'])
plt.xlabel('Quality')
plt.ylabel('Chlorides')
plt.show()

# %% [markdown]
# From the plot we can observe that less chlorides present, bitter the quality of wine

# %%
plt.bar(wine_data['quality'],wine_data['total sulfur dioxide'])
plt.xlabel('Quality')
plt.ylabel('Total sulfur dioxide')
plt.show()

# %% [markdown]
# As we can see total sulfur dioxide doesnt have much correlation with Quality of the wine

# %%
plt.bar(wine_data['quality'],wine_data['alcohol'])
plt.xlabel('Quality')
plt.ylabel('alcohol')
plt.show()

# %% [markdown]
# We can observe that as the content of alcohol increases the quality of the wine incrases

# %%
wine_data.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# key observations-
# Some features are normally distributed such as 'density'and 'pH' but there are more or less skewness in every Independent variables i.e 'Fixed acidity','volatile acidity', 'citric acid', 'residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','sulphates' and 'alcohol' columns are having skewness.
# Major skewness observed in 'residual sugar','chlorides','sulphates','free sulfur dioxide','total sulfur dioxide'

# %%
col = ['residual sugar','chlorides','sulphates','free sulfur dioxide','total sulfur dioxide']
for i in col:
    wine_data[i] = np.log(wine_data[i])

# %%
wine_data.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          1.806864
# chlorides               1.745215
# free sulfur dioxide    -0.234031
# total sulfur dioxide   -0.079323
# density                 0.071288
# pH                      0.193683
# sulphates               0.921867
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
wine_data['quality'] = [0 if x <= 6 else 1 for x in wine_data['quality']]

# %%
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00        0.641854  -2.577022
# 1               7.8             0.880         0.00        0.955511  -2.322788
# 2               7.8             0.760         0.04        0.832909  -2.385967
# 3              11.2             0.280         0.56        0.641854  -2.590267
# 4               7.4             0.700         0.00        0.641854  -2.577022
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08        0.693147  -2.407946
# 1595            5.9             0.550         0.10        0.788457  -2.780621
# 1596            6.3             0.510         0.13        0.832909  -2.577022
# 1597            5.9             0.645         0.12        0.693147  -2.590267
# 1598            6.0             0.310         0.47        1.280934  -2.703063
#
# ...

# %% [markdown]
# Data Visualization

# %%
sns.catplot(x='quality',y='fixed acidity',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='volatile acidity',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='citric acid',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='residual sugar',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='chlorides',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='free sulfur dioxide',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='total sulfur dioxide',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='density',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='pH',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='sulphates',data=wine_data)
plt.show()

# %%
sns.catplot(x='quality',y='alcohol',data=wine_data)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.barplot(x="quality", y="alcohol", data=wine_data)
plt.title("Relationship between Quality of wine and alcohol")
# Out:
# Text(0.5, 1.0, 'Relationship between Quality of wine and alcohol')

# %%
plt.subplot(1,2,2)
sns.barplot(x="quality", y="volatile acidity", data=wine_data)
plt.title("Relationship between Quality of wine and volatile acidity")
# Out:
# Text(0.5, 1.0, 'Relationship between Quality of wine and volatile acidity')

# %%
wine_data.hist(bins=50,figsize=(20,20))
plt.show()

# %%
## using distplot
plt.figure(figsize=(20,20))
plotnumber=1
for column in wine_data:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(wine_data[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
# Detecting outliers using boxplot.

plt.figure(figsize=(15,15),facecolor='white')
num = 1

for col in wine_data:
    if num <= 12:
        ax = plt.subplot(4,3,num)
        sns.boxplot(wine_data[col])
        plt.xlabel(col,fontsize=16)
    num += 1
plt.show()

# %% [markdown]
# key observations:
#
# As we can see ,there are outliers present in almost all columns but majorly in 'Total sulfur dioxide','Free sulfur dioxide','residual sugar'and 'chlorides'.
# Some features are having outliers in both ends but no feature is without outlier.

# %%
wine_data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.174742          0.024278     0.172286
# chlorides                  0.175191          0.108726     0.181780
# free sulfur dioxide       -0.179211          0.016666    -0.089146
# total sulfur dioxide      -0.117900          0.073407    -0.003637
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.204294         -0.300549     0.331516
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.120061         -0.270712     0.214716
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(wine_data.corr(),annot=True,fmt='0.2f', cmap = 'Greens')
# Out:
# <AxesSubplot:>

# %% [markdown]
# pH and citric acid are highly related to fixed acidity, but we need to conduct more analysis

# %%
plt.scatter(wine_data['fixed acidity'], wine_data['pH'])
plt.xlabel('Fixed Acidity')
plt.ylabel('pH')
plt.title('Fixed Acidity vs pH')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(wine_data['fixed acidity'], wine_data['citric acid'])
plt.xlabel('Fixed Acidity')
plt.ylabel('citric acid')
plt.title('Fixed Acidity vs citric acid')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wine_data.corr()['quality'].sort_values(ascending = False)
# Out:
# quality                 1.000000
# alcohol                 0.407315
# sulphates               0.235351
# citric acid             0.214716
# fixed acidity           0.120061
# residual sugar          0.064630
# pH                     -0.057283
# free sulfur dioxide    -0.085463
# chlorides              -0.149043
# density                -0.150460
# total sulfur dioxide   -0.168728
# volatile acidity       -0.270712
# Name: quality, dtype: float64

# %%
plt.figure(figsize = (22,7))
wine_data.corr()['quality'].sort_values(ascending = False).drop(['quality']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize = 15)
plt.ylabel('Target',fontsize = 15)
plt.title("Correlation between label and features using barplot",fontsize=20)
plt.show()

# %% [markdown]
# Overall Conclusion:
#     Alcohol, sulphates, volatile acidity and citric acid are most correlated with quality making them the physiochemical properties making a wine 'Good'

# %%
wine_data['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
sns.countplot(x ='quality', data = wine_data)
wine_data['quality'].unique()
# Out:
# array([0, 1])

# %%
wine_data.plot(kind='box', subplots=True, layout=(4,3), legend=True, figsize=(20,8))
plt.show()

# %%
#Removing Outliers
from scipy.stats import zscore
z=np.abs(zscore(wine_data))
z
threshold=3
np.where(z>3)
# Out:
# (array([  13,   17,   17,   19,   33,   38,   42,   45,   81,   81,   83,
#           86,   91,   92,   95,  106,  106,  120,  126,  127,  142,  144,
#          147,  151,  151,  151,  151,  163,  164,  169,  169,  181,  199,
#          226,  226,  240,  243,  244,  258,  258,  274,  281,  291,  324,
#          325,  339,  347,  374,  381,  391,  396,  400,  442,  442,  451,
#          467,  480,  480,  494,  530,  535,  544,  554,  554,  555,  555,
#          557,  557,  566,  567,  568,  588,  595,  608,  614,  639,  649,
#          652,  652,  652,  666,  672,  690,  692,  695,  723,  724,  730,
#          754,  773,  776,  777,  821,  836,  836,  837,  837,  889,  911,
#          917,  923, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1081,
#         1111, 1114, 1165, 1186, 1235, 1244, 1260, 1269, 1269, 1270, 1270,
#         1299, 1300, 1312, 1316, 1319, 1319, 1321, 1370, 1372, 1374, 1434,
#         1434, 1435, 1435, 1474, 1474, 1476, 1476, 1558, 1570, 1574, 1589]),
# ...

# %%
df=wine_data[(z<3).all(axis=1)]
df.shape
# Out:
# (1482, 12)

# %%
print("Data Loss Percentage :",((wine_data.shape[0]-df.shape[0])/wine_data.shape[0])*100)
# Out:
# Data Loss Percentage : 7.317073170731707

# %% [markdown]
#  #data loss should be less than 10 %.

# %%
x=df.drop('quality',axis=1)
y=df['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00        0.641854  -2.577022
# 1               7.8             0.880         0.00        0.955511  -2.322788
# 2               7.8             0.760         0.04        0.832909  -2.385967
# 3              11.2             0.280         0.56        0.641854  -2.590267
# 4               7.4             0.700         0.00        0.641854  -2.577022
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08        0.693147  -2.407946
# 1595            5.9             0.550         0.10        0.788457  -2.780621
# 1596            6.3             0.510         0.13        0.832909  -2.577022
# 1597            5.9             0.645         0.12        0.693147  -2.590267
# 1598            6.0             0.310         0.47        1.280934  -2.703063
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1482, dtype: int64

# %%
# Balancing the dataset using the SMOTE
import imblearn
from imblearn.over_sampling import SMOTE
x_smote,y_smote = SMOTE().fit_resample(x,y)
y_smote.value_counts()
# Out:
# 0    1279
# 1    1279
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
max_Acc = 0
max_RS = 0

for i in range (1,200):
    x_train, x_test, y_train, y_test = train_test_split(x_smote, y_smote, test_size = 0.20, random_state=i)
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    predlr = lr.predict(x_test)
    acc = accuracy_score(y_test, predlr)
    if acc>max_Acc:
        max_Acc = acc
        max_RS = i
        
print ('Best Accuracy is ', max_Acc, " on Random_State ", max_RS)
# Out:
# Best Accuracy is  0.86328125  on Random_State  46

# %%
#Now splitting the dataset into the Training set and test set
x_train,x_test,y_train,y_test=train_test_split(x_smote,y_smote,test_size=0.20,random_state=46)

# %%
print('Size of X_train : ', x_train.shape)
print('Size of y_train : ', y_train.shape)
print('Size of X_test : ', x_test.shape)
print('Size of Y_test : ', y_test.shape)
# Out:
# Size of X_train :  (2046, 7)
# Size of y_train :  (2046,)
# Size of X_test :  (512, 7)
# Size of Y_test :  (512,)

# %%
#feature scaling
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_test =st.transform(x_test)

# %% [markdown]
# By doing Feature Scaling , we have scaled the data using standard scaler to overcome the issues of biasness.

# %%
#Using PCA (Principal component analysis)for dimensionality reduction
pca=PCA(n_components=0.90)
x_train=pca.fit_transform(x_train)
x_test =pca.transform(x_test)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.937444375693695

# %% [markdown]
# Logistic Regression

# %%
# Now applying Logistic regression
log= LogisticRegression()
log.fit(x_train,y_train)
y_pred1=log.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,y_pred1,output_dict=True))
print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,y_pred1)}\n")
print("Accuracy score",accuracy_score(y_test,y_pred1))
score = cross_val_score(log,x,y,cv=5)
print("Cross val score: ", score.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.835938    0.855469  0.845703    0.845703      0.845894
# recall       0.852590    0.839080  0.845703    0.845835      0.845703
# f1-score     0.844181    0.847195  0.845703    0.845688      0.845718
# support    251.000000  261.000000  0.845703  512.000000    512.000000
#
#  Confusion Matrix:
# [[214  37]
#  [ 42 219]]
#
# Accuracy score 0.845703125
# Cross val score:  0.8731526981526981

# %% [markdown]
# Support Vector Classifier

# %%
svm = SVC()
svm.fit(x_train,y_train)
y_pred2 = svm.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,y_pred2,output_dict=True))
print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,y_pred2)}\n")
print("Accuracy score",accuracy_score(y_test,y_pred2))
score1 = cross_val_score(svm,x,y)
print("Cross val score:",score1.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.941176    0.901460  0.919922    0.921318      0.920930
# recall       0.892430    0.946360  0.919922    0.919395      0.919922
# f1-score     0.916155    0.923364  0.919922    0.919760      0.919830
# support    251.000000  261.000000  0.919922  512.000000    512.000000
#
#  Confusion Matrix:
# [[224  27]
#  [ 14 247]]
#
# Accuracy score 0.919921875
# Cross val score: 0.8758531258531258

# %% [markdown]
# DecisionTreeClassifier

# %%
dt =DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred3= dt.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,y_pred3,output_dict=True))
print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,y_pred3)}\n")
print("Accuracy score",accuracy_score(y_test,y_pred3))
score2 = cross_val_score(dt,x,y)
print("Cross val score: ", score2.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.925620    0.900000  0.912109    0.912810      0.912560
# recall       0.892430    0.931034  0.912109    0.911732      0.912109
# f1-score     0.908722    0.915254  0.912109    0.911988      0.912052
# support    251.000000  261.000000  0.912109  512.000000    512.000000
#
#  Confusion Matrix:
# [[224  27]
#  [ 18 243]]
#
# Accuracy score 0.912109375
# Cross val score:  0.8245449995449995

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred4 = rf.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,y_pred4,output_dict=True))
print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,y_pred4)}\n")
print("Accuracy score",accuracy_score(y_test,y_pred4))
score3 = cross_val_score(rf,x,y)
print("Cross val score: ", score3.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.979253    0.944649  0.960938    0.961951      0.961613
# recall       0.940239    0.980843  0.960938    0.960541      0.960938
# f1-score     0.959350    0.962406  0.960938    0.960878      0.960908
# support    251.000000  261.000000  0.960938  512.000000    512.000000
#
#  Confusion Matrix:
# [[236  15]
#  [  5 256]]
#
# Accuracy score 0.9609375
# Cross val score:  0.8819114569114568

# %% [markdown]
# GradientBoostingClassifier

# %%
gbc= GradientBoostingClassifier()
gbc.fit(x_train,y_train)
y_pred5=gbc.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,y_pred5,output_dict=True))
print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,y_pred5)}\n")
print("Accuracy score:",accuracy_score(y_test,y_pred5))
score4 = cross_val_score(gbc,x,y)
print("Cross val score: ", score4.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.925620    0.900000  0.912109    0.912810      0.912560
# recall       0.892430    0.931034  0.912109    0.911732      0.912109
# f1-score     0.908722    0.915254  0.912109    0.911988      0.912052
# support    251.000000  261.000000  0.912109  512.000000    512.000000
#
#  Confusion Matrix:
# [[224  27]
#  [ 18 243]]
#
# Accuracy score: 0.912109375
# Cross val score:  0.8643802893802894

# %% [markdown]
# KNeighborsClassifier

# %%
knn =KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred6 = knn.predict(x_test)
cfr_report = pd.DataFrame(classification_report(y_test,y_pred6,output_dict=True))
print(f"Classification Report\n{cfr_report}\n")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,y_pred6)}\n")
print("Accuracy score",accuracy_score(y_test,y_pred6))
score5 = cross_val_score(knn,x,y)
print("Cross val score: ", score5.mean())
# Out:
# Classification Report
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.985507    0.845902  0.902344    0.915704      0.914341
# recall       0.812749    0.988506  0.902344    0.900627      0.902344
# f1-score     0.890830    0.911661  0.902344    0.901245      0.901449
# support    251.000000  261.000000  0.902344  512.000000    512.000000
#
#  Confusion Matrix:
# [[204  47]
#  [  3 258]]
#
# Accuracy score 0.90234375
# Cross val score:  0.850869050869051

# %%
final_data = pd.DataFrame({'Model':['LR','SVC','DT','RF','GBC','KNN'],
                    'Accuracy_score':[accuracy_score(y_test,y_pred1)*100,
                           accuracy_score(y_test,y_pred2)*100,
                          accuracy_score(y_test,y_pred3)*100,
                          accuracy_score(y_test,y_pred4)*100,
                          accuracy_score(y_test,y_pred5)*100,
                          accuracy_score(y_test,y_pred6)*100],
                    'Cross_val_score':[score.mean()*100,score1.mean()*100,score2.mean()*100,score3.mean()*100,score4.mean()*100,
                                      score5.mean()*100]})
final_data['Score_diff'] = final_data['Accuracy_score'] - final_data['Cross_val_score']

# %%
final_data
# Out:
#   Model  Accuracy_score  Cross_val_score  Score_diff
# 0    LR       84.570312        87.315270   -2.744957
# 1   SVC       91.992188        87.585313    4.406875
# 2    DT       91.210938        82.454500    8.756438
# 3    RF       96.093750        88.191146    7.902604
# 4   GBC       91.210938        86.438029    4.772909
# 5   KNN       90.234375        85.086905    5.147470

# %% [markdown]
# #We're getting highest accuracy from RandomForestClassifier (96%).

# %% [markdown]
# We have used cross val score to handle the problem of overfitting and underfitting.From the above observation found that the minimum difference of accuracy and cross val score is in Logistic Regression model

# %% [markdown]
# we should plot the ROC-AUC curve to check the best fit model

# %%
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import plot_roc_curve

# %%
disp=plot_roc_curve(dt,x_train,y_train)
plot_roc_curve(log,x_train,y_train,ax=disp.ax_)
plot_roc_curve(svm,x_train,y_train,ax=disp.ax_)
plot_roc_curve(rf,x_train,y_train, ax=disp.ax_)
plot_roc_curve(knn,x_train,y_train,ax=disp.ax_)
plot_roc_curve(gbc,x_train,y_train, ax=disp.ax_)
plt.legend(prop={'size':10},loc='lower right')
plt.show()

# %%
disp=plot_roc_curve(dt,x_test,y_test)
plot_roc_curve(log,x_test,y_test,ax=disp.ax_)
plot_roc_curve(svm,x_test,y_test,ax=disp.ax_)
plot_roc_curve(rf,x_test,y_test, ax=disp.ax_)
plot_roc_curve(knn,x_test,y_test,ax=disp.ax_)
plot_roc_curve(gbc,x_test,y_test, ax=disp.ax_)
plt.legend(prop={'size':10},loc='lower right')
plt.show()

# %% [markdown]
# #From above graphs we observed:
#
# . Model is Overfitting a lot as observed from cross validation score.
# . Logistic Regression has poorer testing accuracy but no overfitting problem
# . Logistic Regression will be my model of choice  with AUC value of 0.92 for testing data but GB and Random Forest can also be considered if accuracy precedes the overfitting issue present.

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
 
# Creating the hyperparameter grid
param_grid = {'solver': ['newton-cg', 'lbfgs', 'liblinear','saga','sag'],
              'penalty': ['l1','l2'],
              'C':[0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000],
             'dual':[True,False],
            'max_iter': [100,110,120,130,140]}
# Instantiating logistic regression classifier
model = LogisticRegression()
# Instantiating the GridSearchCV object
gsv = GridSearchCV( estimator = model,  param_grid = param_grid, cv = 5)
gsv.fit(x_train, y_train)
 
# Print the tuned parameters and score
print("Tuned Logistic Regression Parameters: {}".format(gsv.best_params_))
print("Best score is {}".format(gsv.best_score_))
# Out:
# Tuned Logistic Regression Parameters: {'C': 0.001, 'dual': True, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# Best score is 0.8084024092074662

# %%
model = LogisticRegression(solver = 'liblinear', C = 0.001, penalty = 'l2',dual=False,max_iter=100)

# %%
model.fit(x_train,y_train)
pred = model.predict(x_test)
print("Accuracy score",accuracy_score(y_test,pred)*100)
print("Confusion Matrix",confusion_matrix(y_test,pred))
print("Classification Report",classification_report(y_test,pred))
# Out:
# Accuracy score 84.5703125
# Confusion Matrix [[208  43]
#  [ 36 225]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       251
#            1       0.84      0.86      0.85       261
#
#     accuracy                           0.85       512
#    macro avg       0.85      0.85      0.85       512
# weighted avg       0.85      0.85      0.85       512

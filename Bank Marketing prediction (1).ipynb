# %%
#Importing Required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the data
train_df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset5/main/termdeposit_train.csv")
test_df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset5/main/termdeposit_test.csv")

# %%
#Displaying training dataset
train_df
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
#Displaying Testing Dataset
test_df
# Out:
#           ID  age            job   marital  education default  balance  \
# 0      38441   32       services   married  secondary      no      118
# 1      40403   78        retired  divorced    primary      no     2787
# 2       3709   31  self-employed    single   tertiary      no      144
# 3      37422   57       services    single    primary      no     3777
# 4      12527   45    blue-collar  divorced  secondary      no     -705
# ...      ...  ...            ...       ...        ...     ...      ...
# 13559  23465   39     management   married   tertiary      no       45
# 13560  11743   54    blue-collar   married    primary      no     2281
# 13561  28292   35        retired   married    primary      no      285
# 13562  45163   29         admin.    single  secondary      no      464
# 13563  34839   29         admin.   married  secondary      no        2
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
#Displaying shape of training Dataset
train_df.shape
# Out:
# (31647, 18)

# %%
#Displaying the shape of testing Dataset
test_df.shape
# Out:
# (13564, 17)

# %%
# List the columns in train data
train_df.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
# List the columns in train data
test_df.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome'],
#       dtype='object')

# %%
#Display information about the train dataset
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          31647 non-null  int64
#  1   age         31647 non-null  int64
#  2   job         31647 non-null  object
#  3   marital     31647 non-null  object
#  4   education   31647 non-null  object
#  5   default     31647 non-null  object
#  6   balance     31647 non-null  int64
#  7   housing     31647 non-null  object
#  8   loan        31647 non-null  object
#  9   contact     31647 non-null  object
#  10  day         31647 non-null  int64
#  11  month       31647 non-null  object
#  12  duration    31647 non-null  int64
#  13  campaign    31647 non-null  int64
#  14  pdays       31647 non-null  int64
#  15  previous    31647 non-null  int64
#  16  poutcome    31647 non-null  object
#  17  subscribed  31647 non-null  object
# dtypes: int64(8), object(10)
# memory usage: 4.3+ MB

# %%
#Display the information about test dataset
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13564 entries, 0 to 13563
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         13564 non-null  int64
#  1   age        13564 non-null  int64
#  2   job        13564 non-null  object
#  3   marital    13564 non-null  object
#  4   education  13564 non-null  object
#  5   default    13564 non-null  object
#  6   balance    13564 non-null  int64
#  7   housing    13564 non-null  object
#  8   loan       13564 non-null  object
#  9   contact    13564 non-null  object
#  10  day        13564 non-null  int64
#  11  month      13564 non-null  object
#  12  duration   13564 non-null  int64
#  13  campaign   13564 non-null  int64
#  14  pdays      13564 non-null  int64
#  15  previous   13564 non-null  int64
#  16  poutcome   13564 non-null  object
# dtypes: int64(8), object(9)
# memory usage: 1.8+ MB

# %%
#Checking if any null values is present in train dataset
train_df.isnull().sum()
# Out:
# ID            0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
#Checking if any null values is present in test dataset
test_df.isnull().sum()
# Out:
# ID           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
#Checking total number of unique values in target variable.
train_df['subscribed'].value_counts()
# Out:
# no     27932
# yes     3715
# Name: subscribed, dtype: int64

# %%
#Plotting the count of target variable.
sns.countplot(data=train_df, x='subscribed')
# Out:
# <AxesSubplot:xlabel='subscribed', ylabel='count'>

# %%
# Value counts for every feature to check the missing again or unique values
for i in train_df.columns:
    print(train_df[i].value_counts())
    print('\n','**********************************')
# Out:
# 26110    1
# 13339    1
# 39681    1
# 15135    1
# 26037    1
#         ..
# 1247     1
# 15584    1
# 25376    1
# 38699    1
# 14156    1
# Name: ID, Length: 31647, dtype: int64
#
#  **********************************
# 32    1457
# 31    1417
# 33    1406
# 34    1321
# 35    1314
#       ...
# 92       1
# 95       1
# 93       1
# 94       1
# 90       1
# Name: age, Length: 76, dtype: int64
#
#  **********************************
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: job, dtype: int64
#
#  **********************************
# married     19095
# single       8922
# divorced     3630
# Name: marital, dtype: int64
#
#  **********************************
# secondary    16224
# tertiary      9301
# primary       4808
# ...

# %%
# Value counts for every feature to check the missing again or unique values
for i in test_df.columns:
    print(test_df[i].value_counts())
    print('\n','**********************************')
# Out:
# 38441    1
# 23664    1
# 23378    1
# 18945    1
# 32574    1
#         ..
# 4606     1
# 23686    1
# 35672    1
# 8550     1
# 34839    1
# Name: ID, Length: 13564, dtype: int64
#
#  **********************************
# 32    628
# 34    609
# 35    580
# 31    579
# 33    566
#      ...
# 95      1
# 86      1
# 92      1
# 89      1
# 90      1
# Name: age, Length: 75, dtype: int64
#
#  **********************************
# blue-collar      2890
# management       2819
# technician       2290
# admin.           1540
# services         1251
# retired           690
# entrepreneur      479
# self-employed     456
# unemployed        398
# housemaid         366
# student           303
# unknown            82
# Name: job, dtype: int64
#
#  **********************************
# married     8119
# single      3868
# divorced    1577
# Name: marital, dtype: int64
#
#  **********************************
# secondary    6978
# tertiary     4000
# primary      2043
# unknown       543
# ...

# %%
# Check duplicates records for train data
train_df.duplicated().sum()
# Out:
# 0

# %%
# Check duplicates records for test data
test_df.duplicated().sum()
# Out:
# 0

# %%
#Display the total number of unknown values present in train dataset
train_df[train_df == 'unknown'].count()
# Out:
# ID                0
# age               0
# job             206
# marital           0
# education      1314
# default           0
# balance           0
# housing           0
# loan              0
# contact        9177
# day               0
# month             0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome      25929
# subscribed        0
# dtype: int64

# %%
#Display the total number of unknown values present in test dataset
test_df[test_df == 'unknown'].count()
# Out:
# ID               0
# age              0
# job             82
# marital          0
# education      543
# default          0
# balance          0
# housing          0
# loan             0
# contact       3843
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome     11030
# dtype: int64

# %%
# Drop 'ID' feature in both train & test data .
train_df.drop('ID',axis=1,inplace=True)
test_df.drop('ID',axis=1,inplace=True)

# %%
# Handling unknown values.
def unknwn_value(value):
    if ((value.dtype =='float64') or (value.dtype =='int64')):
        value[value == -1] = np.nan
        value=value.fillna(value.median())
    else:
        value[value=='unknown'] = np.nan
        value=value.fillna(value.mode()[0])
        
    return value

# %%
#applying values in unknown values 
train_df = train_df.apply(unknwn_value)
test_df = test_df.apply(unknwn_value)

# %%
#rechecking the unknown values 
train_df[train_df == 'unknown'].count()
# Out:
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
test_df[test_df == 'unknown'].count()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
# Splitting the training dataset in Categorical and numerical for visualization and further analysis
# Categorical
categorical_train=train_df.select_dtypes(include=['object'])

# Numerical
numerical_train= train_df.select_dtypes(include=['float64','int64'])

# %%
categorical_train.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
numerical_train.columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
# Splitting the testing dataset in Categorical and numerical for visualization and further analysis
# Categorical
categorical_test=test_df.select_dtypes(include=['object'])

# Numerical
numerical_test= test_df.select_dtypes(include=['float64','int64'])

# %%
categorical_test.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome'],
#       dtype='object')

# %%
numerical_test.columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
# checking the statistical summary of numerical train data .
numerical_train.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  31647.000000   31647.000000  31647.000000  31647.000000  31647.000000
# mean      40.957247    1364.390148     15.835466    258.113534      2.765697
# std       10.625134    3028.116241      8.337097    257.118973      3.113830
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      74.000000      8.000000    104.000000      1.000000
# 50%       39.000000     451.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1431.000000     21.000000    318.500000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  31647.000000  31647.000000
# mean     198.493349      0.574272
# std       50.423500      2.422529
# min        1.000000      0.000000
# 25%      193.000000      0.000000
# 50%      193.000000      0.000000
# ...

# %%
 # checking the statistical summary of numerical test data .
numerical_test.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  13564.000000  13564.000000  13564.000000  13564.000000  13564.000000
# mean      40.887128   1358.991964     15.738646    258.278679      2.759510
# std       10.604108   3082.758090      8.288174    258.488648      3.060928
# min       18.000000  -3313.000000      1.000000      0.000000      1.000000
# 25%       33.000000     72.000000      8.000000    102.000000      1.000000
# 50%       39.000000    447.000000     16.000000    180.000000      2.000000
# 75%       48.000000   1413.250000     21.000000    319.000000      3.000000
# max       95.000000  98417.000000     31.000000   3253.000000     58.000000
#
#               pdays      previous
# count  13564.000000  13564.000000
# mean     201.032218      0.594441
# std       51.395376      1.998193
# min        1.000000      0.000000
# 25%      195.000000      0.000000
# 50%      195.000000      0.000000
# 75%      195.000000      0.000000
# ...

# %% [markdown]
# OBSERVATIONS -
# All the columns has same count as 31647 which means that there is no null values in the dataset.
# There are outliers are present in numerical columns as we can see huge difference between 75% to max value.
# Mean is greater than Median (50%) which means that the data is skewed to right.

# %%
for i in categorical_train:
    print(pd.crosstab(categorical_train[i],categorical_train['subscribed']))
    print('\n','--------------------------------------------------------')
# Out:
# subscribed       no  yes
# job
# admin.         3179  452
# blue-collar    6533  515
# entrepreneur    923   85
# housemaid       795   79
# management     5716  923
# retired        1212  362
# self-employed   983  140
# services       2649  254
# student         453  182
# technician     4713  594
# unemployed      776  129
#
#  --------------------------------------------------------
# subscribed     no   yes
# marital
# divorced     3185   445
# married     17176  1919
# single       7571  1351
#
#  --------------------------------------------------------
# subscribed     no   yes
# education
# primary      4381   427
# secondary   15665  1873
# tertiary     7886  1415
#
#  --------------------------------------------------------
# subscribed     no   yes
# default
# no          27388  3674
# yes           544    41
#
#  --------------------------------------------------------
# subscribed     no   yes
# housing
# no          11698  2365
# yes         16234  1350
#
# ...

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize=(15,60), facecolor='lightyellow')
plotnumber=1
for column in categorical_train:
    if plotnumber<=10:
        ax=plt.subplot(10,1,plotnumber)
        sns.histplot(train_df[column], color ='r')
        plt.xlabel(column, fontsize=15)
    plotnumber+=1
plt.show()

# %%
for i in categorical_train:
    plt.figure(figsize = (15,6))
    sns.countplot(data= train_df, x = i, hue = 'subscribed');

# %% [markdown]
# Observations:
# Majority of blue-collar job people didnt subscribed to term deposit while management job did subscribed to term deposit.

# %% [markdown]
# People with secondary education are targeted more compared with other education.
# People who have taken housing and personal loan have not subscribed.
# People are more contacted through cellular phones and subscribed more than other means of contact
# People have not been contacted high during the month of May,June,July,Aug.
# Married people subcribed more followed by single and divorced.
# Overall People subscribed count is too low

# %%
# Visualizing the train dataset in histplot for all the columns
for i in numerical_train.columns:
    plt.figure(figsize=(10,5))
    sns.histplot(train_df,x = i,color='blue',kde=True)
    plt.xlabel(i,fontsize=15)
    plt.ylabel('Count',fontsize=15)
plt.show()

# %%
# Visualizing the test dataset in histplot for all the columns
for i in numerical_test.columns:
    plt.figure(figsize=(10,5))
    sns.histplot(test_df,x = i,color='pink',kde=True)
    plt.xlabel(i,fontsize=15)
    plt.ylabel('Count',fontsize=15)
plt.show()

# %%
# Visualizing the Numerical columns with distribution plot to check the distribution

plt.figure(figsize=(15,20))
number = 1
for i in numerical_train:
    if number <=7:
        ax=plt.subplot(4,2,number)
        sns.distplot(train_df[i],color='#f02d74')
        plt.xlabel(i,fontsize=10)
    number+=1
plt.show()

# %% [markdown]
# Almost in all data is skewed towards right

# %%
# Visualizing the Numerical columns with distribution plot to check the distribution

plt.figure(figsize=(15,20))
number = 1
for i in numerical_test:
    if number <=7:
        ax=plt.subplot(4,2,number)
        sns.distplot(test_df[i],color='#f02d74')
        plt.xlabel(i,fontsize=10)
    number+=1
plt.show()

# %%
# Visualizing the Numerical columns in boxplot to identify outliers
for col in numerical_train.columns:
    sns.boxplot(train_df[col],color='green')
    plt.show()

# %%
# Visualizing the Numerical columns in boxplot to identify outliers
for col in numerical_test.columns:
    sns.boxplot(test_df[col],color='red')
    plt.show()

# %% [markdown]
# Outliers are present

# %%
#Removing the outliers using zscore for train dataset
from scipy.stats import zscore
z_col = zscore(numerical_train[['age','balance','duration','campaign','pdays','previous']])
z=np.abs(z_col)
#threshold is 3
num_train= numerical_train[(z<3).all(axis=1)]

# %%
numerical_train.shape
# Out:
# (31647, 7)

# %%
num_train.shape
# Out:
# (28270, 7)

# %%
print("Data Loss Percentage :",((numerical_train.shape[0]-num_train.shape[0])/numerical_train.shape[0])*100)
# Out:
# Data Loss Percentage : 10.670837678136948

# %%
#Removing the outliers using zscore for test dataset
from scipy.stats import zscore
z_col = zscore(numerical_test[['age','balance','duration','campaign','pdays','previous']])
z=np.abs(z_col)
#threshold is 3
num_test= numerical_test[(z<3).all(axis=1)]

# %%
numerical_test.shape
# Out:
# (13564, 7)

# %%
num_test.shape
# Out:
# (12052, 7)

# %%
print("Data loss %: ",((numerical_test.shape[0]-num_test.shape[0])/numerical_test.shape[0])*100)
# Out:
# Data loss %:  11.147154231790033

# %%
num_train.skew()
# Out:
# age         0.441744
# balance     2.444970
# day         0.079564
# duration    1.596033
# campaign    2.065703
# pdays       1.184862
# previous    3.619925
# dtype: float64

# %%
num_test.skew()
# Out:
# age         0.438910
# balance     2.476504
# day         0.102528
# duration    1.579090
# campaign    1.956723
# pdays       1.401685
# previous    3.387209
# dtype: float64

# %%
# Removing skewness using power transform function in Numerical columns
from sklearn.preprocessing import PowerTransformer 
col =['balance','duration', 'campaign', 'pdays', 'previous']

pt = PowerTransformer(method='yeo-johnson')
num_train[col]= pt.fit_transform(num_train[col].values)
num_test[col] = pt.fit_transform(num_test[col].values)

# %%
num_train.skew().sort_values()
# Out:
# duration    0.003419
# day         0.079564
# campaign    0.205179
# balance     0.210344
# pdays       0.407317
# age         0.441744
# previous    2.027519
# dtype: float64

# %%
num_test.skew().sort_values()
# Out:
# duration    0.002222
# day         0.102528
# campaign    0.203709
# pdays       0.338772
# age         0.438910
# balance     0.602344
# previous    1.988411
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder 
le= LabelEncoder()
for i in categorical_train.columns:
    if(categorical_train[i].dtypes=='object'):
        categorical_train[i]=le.fit_transform(categorical_train[i].values.reshape(-1,1))
categorical_train.head(10)
# Out:
#    job  marital  education  default  housing  loan  contact  month  poutcome  \
# 0    0        1          1        0        0     0        1      9         0
# 1    1        1          1        0        0     0        0      5         0
# 2    7        1          1        0        1     0        0      5         0
# 3    4        0          2        0        0     0        0      6         2
# 4    9        1          1        0        1     0        0      3         0
# 5    4        2          2        0        1     0        0      3         0
# 6    5        1          1        0        0     0        1      5         0
# 7    9        2          1        0        0     0        0      6         0
# 8    1        0          1        0        1     0        0      3         0
# 9    0        1          1        0        0     0        0     11         0
#
#    subscribed
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0
# 5           0
# ...

# %%
# Merging both numerical train and categorical train data for final train data 
final_train = pd.concat([num_train,categorical_train], axis=1)

# %%
final_train.isnull().sum()
# Out:
# age           3377
# balance       3377
# day           3377
# duration      3377
# campaign      3377
# pdays         3377
# previous      3377
# job              0
# marital          0
# education        0
# default          0
# housing          0
# loan             0
# contact          0
# month            0
# poutcome         0
# subscribed       0
# dtype: int64

# %%
# Drop NAN indexes after concatenating
final_train.dropna(inplace=True)
final_train
# Out:
#         age   balance   day  duration  campaign     pdays  previous  job  \
# 0      56.0  0.577746  19.0 -1.507084  0.171773 -0.006698 -0.410262    0
# 1      31.0 -0.564469  20.0 -0.799413  0.171773 -0.006698 -0.410262    1
# 2      27.0  0.012897  18.0  0.328969 -1.105208 -0.006698 -0.410262    7
# 3      57.0  1.256744  22.0  2.211586 -1.105208 -3.750699  2.455079    4
# 4      31.0 -0.469084   4.0  0.947057 -1.105208 -0.006698 -0.410262    9
# ...     ...       ...   ...       ...       ...       ...       ...  ...
# 31640  43.0  1.100561  20.0 -1.837560  1.168918 -0.006698 -0.410262    4
# 31641  37.0  0.246034   6.0  1.163265  0.171773 -0.006698 -0.410262    9
# 31642  29.0 -0.568061  12.0 -0.537815  0.171773 -0.006698 -0.410262    4
# 31643  53.0 -0.293103   5.0  1.150072  0.171773 -0.006698 -0.410262    4
# 31644  32.0 -0.336841   7.0 -1.660079  0.798231 -0.006698 -0.410262    4
#
#        marital  education  default  housing  loan  contact  month  poutcome  \
# ...

# %%
final_train.isnull().any().sum()
# Out:
# 0

# %%
#Label Encoding the dataset
from sklearn.preprocessing import LabelEncoder 
le= LabelEncoder()
for i in categorical_test.columns:
    if(categorical_test[i].dtypes=='object'):
        categorical_test[i]=le.fit_transform(categorical_test[i].values.reshape(-1,1))
categorical_test.head(10)
# Out:
#    job  marital  education  default  housing  loan  contact  month  poutcome
# 0    7        1          1        0        1     0        0      8         0
# 1    5        0          0        0        0     0        1      5         0
# 2    6        2          2        0        1     0        0      8         0
# 3    7        2          0        0        1     0        1      8         0
# 4    1        0          1        0        0     1        0      5         0
# 5    4        2          2        0        1     0        0      5         0
# 6    1        2          1        0        1     0        0      8         0
# 7    4        1          1        0        0     0        0      6         0
# 8    9        0          2        0        0     0        0      7         0
# 9    0        2          0        0        1     0        0      8         0

# %%
final_test = pd.concat([num_test,categorical_test],axis = 1)
final_test
# Out:
#         age   balance   day  duration  campaign    pdays  previous  job  \
# 0      32.0 -0.461418  15.0 -2.116359  1.590603 -0.01866 -0.415986    7
# 2      31.0 -0.442511  16.0  1.806711 -1.103057 -0.01866 -0.415986    6
# 3      57.0  1.478416  13.0 -1.123693  0.171044 -0.01866 -0.415986    7
# 4      45.0 -2.573283   3.0 -0.578006 -1.103057 -0.01866 -0.415986    1
# 5      32.0 -0.560653  22.0  1.202973  0.171044 -0.01866 -0.415986    4
# ...     ...       ...   ...       ...       ...      ...       ...  ...
# 13498   NaN       NaN   NaN       NaN       NaN      NaN       NaN    4
# 13512   NaN       NaN   NaN       NaN       NaN      NaN       NaN    0
# 13550   NaN       NaN   NaN       NaN       NaN      NaN       NaN    4
# 13555   NaN       NaN   NaN       NaN       NaN      NaN       NaN    4
# 13563   NaN       NaN   NaN       NaN       NaN      NaN       NaN    0
#
#        marital  education  default  housing  loan  contact  month  poutcome
# ...

# %%
final_test.isnull().sum()
# Out:
# age          1512
# balance      1512
# day          1512
# duration     1512
# campaign     1512
# pdays        1512
# previous     1512
# job             0
# marital         0
# education       0
# default         0
# housing         0
# loan            0
# contact         0
# month           0
# poutcome        0
# dtype: int64

# %%
final_test.dropna(inplace = True)
final_test
# Out:
#         age   balance   day  duration  campaign    pdays  previous  job  \
# 0      32.0 -0.461418  15.0 -2.116359  1.590603 -0.01866 -0.415986    7
# 2      31.0 -0.442511  16.0  1.806711 -1.103057 -0.01866 -0.415986    6
# 3      57.0  1.478416  13.0 -1.123693  0.171044 -0.01866 -0.415986    7
# 4      45.0 -2.573283   3.0 -0.578006 -1.103057 -0.01866 -0.415986    1
# 5      32.0 -0.560653  22.0  1.202973  0.171044 -0.01866 -0.415986    4
# ...     ...       ...   ...       ...       ...      ...       ...  ...
# 13558  32.0 -0.453359   7.0  0.178313 -1.103057 -0.01866 -0.415986    9
# 13559  39.0 -0.518129  28.0 -0.257237  1.170413 -0.01866 -0.415986    4
# 13560  54.0  0.753962  20.0 -0.181510 -1.103057 -0.01866 -0.415986    1
# 13561  35.0 -0.346075  29.0 -0.353601 -1.103057 -0.01866 -0.415986    5
# 13562  29.0 -0.232333   9.0  0.148846  0.171044 -3.59845  2.422346    0
#
#        marital  education  default  housing  loan  contact  month  poutcome
# ...

# %%
final_test.isnull().any().sum()
# Out:
# 0

# %%
#Descriptive Analysis of final train dataset
final_train.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  28270.000000  2.827000e+04  28270.000000  2.827000e+04  2.827000e+04
# mean      40.626212  6.733403e-17     15.827414  3.356903e-16 -2.268005e-16
# std       10.067783  1.000018e+00      8.355678  1.000018e+00  1.000018e+00
# min       18.000000 -2.476556e+01      1.000000 -3.957346e+00 -1.105208e+00
# 25%       33.000000 -5.084746e-01      8.000000 -6.571398e-01 -1.105208e+00
# 50%       39.000000 -2.609407e-01     16.000000 -4.304276e-02  1.717733e-01
# 75%       48.000000  2.650909e-01     21.000000  6.485461e-01  7.982309e-01
# max       72.000000  4.456877e+00     31.000000  2.501629e+00  2.056356e+00
#
#               pdays      previous           job       marital     education  \
# count  2.827000e+04  2.827000e+04  28270.000000  28270.000000  28270.000000
# mean  -1.675579e-15 -2.831010e-16      4.269650      1.168023      1.140255
# ...

# %%
#Descriptive Analysis of final test dataset
final_test.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  12052.000000  1.205200e+04  12052.000000  1.205200e+04  1.205200e+04
# mean      40.639811  1.488419e-17     15.706273 -2.719549e-16 -6.063276e-16
# std       10.107124  1.000041e+00      8.255344  1.000041e+00  1.000041e+00
# min       18.000000 -1.212009e+01      1.000000 -3.839683e+00 -1.103057e+00
# 25%       33.000000 -5.010642e-01      8.000000 -6.581818e-01 -1.103057e+00
# 50%       39.000000 -2.568484e-01     16.000000 -4.742993e-02  1.710436e-01
# 75%       48.000000  2.628715e-01     21.000000  6.478777e-01  7.982973e-01
# max       72.000000  4.442579e+00     31.000000  2.510302e+00  2.020263e+00
#
#               pdays      previous           job       marital     education  \
# count  1.205200e+04  1.205200e+04  12052.000000  12052.000000  12052.000000
# mean   2.037681e-15 -4.489900e-16      4.294142      1.167441      1.142217
# ...

# %%
#Displaying the correlation in final train dataset
final_train.corr()
# Out:
#                  age   balance       day  duration  campaign     pdays  \
# age         1.000000  0.083967 -0.007773 -0.030276  0.042533 -0.028493
# balance     0.083967  1.000000 -0.003241  0.021597 -0.017166 -0.063669
# day        -0.007773 -0.003241  1.000000 -0.041764  0.126831 -0.038331
# duration   -0.030276  0.021597 -0.041764  1.000000 -0.089857 -0.013637
# campaign    0.042533 -0.017166  0.126831 -0.089857  1.000000  0.031277
# pdays      -0.028493 -0.063669 -0.038331 -0.013637  0.031277  1.000000
# previous   -0.007911  0.068730 -0.056160  0.030210 -0.109904  0.015716
# job        -0.041786  0.020988  0.024401 -0.001324  0.010703 -0.037156
# marital    -0.411642  0.021010 -0.008792  0.015350 -0.036541 -0.012457
# education  -0.153137  0.046311  0.019169  0.004213 -0.007368 -0.067381
# default    -0.009991 -0.164662  0.006838 -0.000438  0.011243  0.008402
# housing    -0.156564 -0.077146 -0.018309  0.011154 -0.045101  0.159007
# ...

# %%
#Displaying the correlation in final test dataset
final_test.corr()
# Out:
#                 age   balance       day  duration  campaign     pdays  \
# age        1.000000  0.092024 -0.008450 -0.018087  0.038677 -0.050515
# balance    0.092024  1.000000  0.004393  0.025138 -0.019407 -0.075959
# day       -0.008450  0.004393  1.000000 -0.029873  0.123617 -0.036044
# duration  -0.018087  0.025138 -0.029873  1.000000 -0.094272 -0.013817
# campaign   0.038677 -0.019407  0.123617 -0.094272  1.000000  0.021184
# pdays     -0.050515 -0.075959 -0.036044 -0.013817  0.021184  1.000000
# previous  -0.005636  0.072836 -0.078009  0.028881 -0.121162  0.044170
# job       -0.037312  0.006419  0.022089  0.009564  0.015548 -0.045765
# marital   -0.402085  0.013305  0.002519  0.002581 -0.023390  0.001718
# education -0.164888  0.050452  0.040491 -0.007213  0.013343 -0.072713
# default   -0.022063 -0.159837  0.004480 -0.005635  0.014285  0.001053
# housing   -0.173060 -0.084161 -0.023434  0.005578 -0.039981  0.155888
# ...

# %%
#Visualisation of heatmap for final train dataset
plt.figure(figsize = (20,18))
sns.heatmap(final_train.corr(),annot = True, fmt = '.2f', linewidth = 0.3)
# Out:
# <AxesSubplot:>

# %%
# heatmap correlation for final test dataset
plt.figure(figsize = (20,16))
sns.heatmap(final_test.corr(), annot=True , linewidth=0.3, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
final_train.corr()['subscribed'].sort_values(ascending = False)
# Out:
# subscribed    1.000000
# duration      0.318024
# poutcome      0.303474
# previous      0.179725
# education     0.079846
# balance       0.075642
# marital       0.055378
# job           0.035230
# contact       0.003980
# age          -0.006525
# default      -0.013721
# month        -0.023741
# day          -0.030330
# loan         -0.074558
# campaign     -0.081046
# pdays        -0.139980
# housing      -0.145518
# Name: subscribed, dtype: float64

# %%
plt.figure(figsize = (22,15))
final_train.corr()['subscribed'].sort_values(ascending = False).drop(['subscribed']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize = 15)
plt.ylabel('Target',fontsize = 15)
plt.title("Correlation between label and features using barplot",fontsize=20)
plt.show()

# %%
#Concatenating to get final dataset
df= pd.concat([final_train,final_test])
# Drop NAN indexes after concatenating
df.dropna(inplace=True)
df
# Out:
#         age   balance   day  duration  campaign     pdays  previous  job  \
# 0      56.0  0.577746  19.0 -1.507084  0.171773 -0.006698 -0.410262    0
# 1      31.0 -0.564469  20.0 -0.799413  0.171773 -0.006698 -0.410262    1
# 2      27.0  0.012897  18.0  0.328969 -1.105208 -0.006698 -0.410262    7
# 3      57.0  1.256744  22.0  2.211586 -1.105208 -3.750699  2.455079    4
# 4      31.0 -0.469084   4.0  0.947057 -1.105208 -0.006698 -0.410262    9
# ...     ...       ...   ...       ...       ...       ...       ...  ...
# 31640  43.0  1.100561  20.0 -1.837560  1.168918 -0.006698 -0.410262    4
# 31641  37.0  0.246034   6.0  1.163265  0.171773 -0.006698 -0.410262    9
# 31642  29.0 -0.568061  12.0 -0.537815  0.171773 -0.006698 -0.410262    4
# 31643  53.0 -0.293103   5.0  1.150072  0.171773 -0.006698 -0.410262    4
# 31644  32.0 -0.336841   7.0 -1.660079  0.798231 -0.006698 -0.410262    4
#
#        marital  education  default  housing  loan  contact  month  poutcome  \
# ...

# %%
#Splitting the dataset
x=df.drop('subscribed',axis=1)
y=df['subscribed']

# %%
x
# Out:
#         age   balance   day  duration  campaign     pdays  previous  job  \
# 0      56.0  0.577746  19.0 -1.507084  0.171773 -0.006698 -0.410262    0
# 1      31.0 -0.564469  20.0 -0.799413  0.171773 -0.006698 -0.410262    1
# 2      27.0  0.012897  18.0  0.328969 -1.105208 -0.006698 -0.410262    7
# 3      57.0  1.256744  22.0  2.211586 -1.105208 -3.750699  2.455079    4
# 4      31.0 -0.469084   4.0  0.947057 -1.105208 -0.006698 -0.410262    9
# ...     ...       ...   ...       ...       ...       ...       ...  ...
# 31640  43.0  1.100561  20.0 -1.837560  1.168918 -0.006698 -0.410262    4
# 31641  37.0  0.246034   6.0  1.163265  0.171773 -0.006698 -0.410262    9
# 31642  29.0 -0.568061  12.0 -0.537815  0.171773 -0.006698 -0.410262    4
# 31643  53.0 -0.293103   5.0  1.150072  0.171773 -0.006698 -0.410262    4
# 31644  32.0 -0.336841   7.0 -1.660079  0.798231 -0.006698 -0.410262    4
#
#        marital  education  default  housing  loan  contact  month  poutcome
# ...

# %%
y
# Out:
# 0        0.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        0.0
#         ...
# 31640    0.0
# 31641    0.0
# 31642    0.0
# 31643    1.0
# 31644    0.0
# Name: subscribed, Length: 28270, dtype: float64

# %%
x.shape
# Out:
# (28270, 16)

# %%
y.shape
# Out:
# (28270,)

# %%
#Feature scaling the dataset using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
x_scaled=pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
x = x_scaled
x
# Out:
#             age   balance       day  duration  campaign     pdays  previous  \
# 0      1.527055  0.577746  0.379699 -1.507084  0.171773 -0.006698 -0.410262
# 1     -0.956157 -0.564469  0.499380 -0.799413  0.171773 -0.006698 -0.410262
# 2     -1.353471  0.012897  0.260018  0.328969 -1.105208 -0.006698 -0.410262
# 3      1.626384  1.256744  0.738743  2.211586 -1.105208 -3.750699  2.455079
# 4     -0.956157 -0.469084 -1.415519  0.947057 -1.105208 -0.006698 -0.410262
# ...         ...       ...       ...       ...       ...       ...       ...
# 28265  0.235785  1.100561  0.499380 -1.837560  1.168918 -0.006698 -0.410262
# 28266 -0.360186  0.246034 -1.176157  1.163265  0.171773 -0.006698 -0.410262
# 28267 -1.154814 -0.568061 -0.458070 -0.537815  0.171773 -0.006698 -0.410262
# 28268  1.229070 -0.293103 -1.295838  1.150072  0.171773 -0.006698 -0.410262
# 28269 -0.856829 -0.336841 -1.056476 -1.660079  0.798231 -0.006698 -0.410262
#
# ...

# %%
# Checking the Variance Inflation Factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
print(vif)
# Out:
#     VIF Factor   Features
# 0     1.296147        age
# 1     1.068224    balance
# 2     1.023417        day
# 3     1.018485   duration
# 4     1.060464   campaign
# 5     1.124844      pdays
# 6     1.556533   previous
# 7     1.052160        job
# 8     1.229535    marital
# 9     1.086683  education
# 10    1.033925    default
# 11    1.184532    housing
# 12    1.025409       loan
# 13    1.031498    contact
# 14    1.128407      month
# 15    1.613373   poutcome

# %%
y.value_counts()
# Out:
# 0.0    25408
# 1.0     2862
# Name: subscribed, dtype: int64

# %%
#Handling the imbalanced dataset
from imblearn.over_sampling import SMOTE
smt= SMOTE()
x_smote,y_smote=smt.fit_resample(x,y)
y_smote.value_counts()
# Out:
# 0.0    25408
# 1.0    25408
# Name: subscribed, dtype: int64

# %% [markdown]
# #Model Building

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score   
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve

# %%
Model= [RandomForestClassifier(),LogisticRegression(),DecisionTreeClassifier(), SVC(), GradientBoostingClassifier()]

# %%
for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .30, random_state=i)
    for m in Model:
        maxAcc = 0
        maxRs = 0
        m.fit(x_train,y_train)
        m.score(x_train,y_train)
        pred = m.predict(x_test)
        acc = accuracy_score(y_test,pred)
        if acc>maxAcc:
            maxAcc = acc
            maxRs=i
print("Best Accuracy is:", maxAcc, "on Random State:", maxRs)
# Out:
# Best Accuracy is: 0.9136894234170498 on Random State: 49

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .30, random_state=49)

# %%
#Splitting the data into training and testing Data.
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (19789, 16)
# (8481, 16)
# (19789,)
# (8481,)

# %%
#Using PCA (Principal component analysis)for dimensionality reduction
from sklearn.decomposition import PCA
pca=PCA(n_components=0.95)
x_train=pca.fit_transform(x_train)
x_test =pca.transform(x_test)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9760649362145764

# %%
from sklearn.model_selection import cross_val_score
for m in Model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print(m)
    print(f" Accuracy score is: {accuracy_score(y_test,predm)*100:.2f}")
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,predm))
    print ('\n','Classification Report:','\n',classification_report(y_test,predm))
    score = cross_val_score(m,x,y,cv=5)
    print('\n',f"Cross val score: {score.mean()*100:.2f}%")
    print(f'\n Difference between accuracy score and cross val score {(accuracy_score(y_test,predm)-score.mean())*100:.2f}')
    print('\n')
# Out:
# RandomForestClassifier()
#  Accuracy score is: 91.27
#
#  Confusion matrix:
#  [[7555  101]
#  [ 639  186]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.92      0.99      0.95      7656
#          1.0       0.65      0.23      0.33       825
#
#     accuracy                           0.91      8481
#    macro avg       0.79      0.61      0.64      8481
# weighted avg       0.90      0.91      0.89      8481
#
#
#  Cross val score: 91.25%
#
#  Difference between accuracy score and cross val score 0.03
#
#
# LogisticRegression()
#  Accuracy score is: 91.30
#
#  Confusion matrix:
#  [[7524  132]
#  [ 606  219]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.93      0.98      0.95      7656
#          1.0       0.62      0.27      0.37       825
#
#     accuracy                           0.91      8481
#    macro avg       0.77      0.62      0.66      8481
# ...

# %% [markdown]
# Observation- RandomForestClassifier is the best model.m

# %% [markdown]
# # HyperParameter Tuning

# %%
parameters={'n_estimators':[200,500,700,1000],'max_depth':[10,20,25,30],
          'max_features':['sqrt','auto'],'min_samples_split':[2,5,10],
          'min_samples_leaf':[1,2,4]}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [30], 'max_features': ['sqrt', 'auto'],
#                          'min_samples_leaf': [1], 'min_samples_split': [10],
#                          'n_estimators': [700]})

# %%
GCV.best_params_
# Out:
# {'max_depth': 30,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 10,
#  'n_estimators': 700}

# %%
GCV.best_score_
# Out:
# 0.9094446962246883

# %%
Final_model = RandomForestClassifier(min_samples_split= 10,min_samples_leaf=1,max_features='sqrt',max_depth=30,
                       n_estimators=500)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 91.33356915458083

# %%
print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,pred))
# Out:
#  Confusion matrix:
#  [[7562   94]
#  [ 641  184]]

# %%
mat = confusion_matrix(y_test,pred)
plt.subplots(figsize=(12,8))
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('Original label')
plt.ylabel('predicted label')
# Out:
# Text(277.72222222222223, 0.5, 'predicted label')

# %%
#Saving the model using .pkl
import pickle

finalmodel = 'Bank_Prediction.pkl'
pickle.dump(Final_model,open(finalmodel,'wb'))

# %%
load_model = pickle.load(open('Bank_Prediction.pkl','rb'))
result = load_model.score(x_test,y_test)
pred_test = load_model.predict(x_test)

print("Random Forest Classifier :",result*100,'%')
# Out:
# Random Forest Classifier : 91.33356915458083 %

# %%
#Importing Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the Dataset
glass_df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv", names =  ['Id','RI','NA','Mg','Al','Si','K','Ca','Ba','Fe','Type'])
glass_df
# Out:
#       Id       RI     NA    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 11 columns]

# %%
#Display the top 5 rows and columns 
glass_df.head(5)
# Out:
#    Id       RI     NA    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
#Display the bottom 5 rows and columns 
glass_df.tail(5)
# Out:
#       Id       RI     NA   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
#Display Information about dataset
glass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      214 non-null    int64
#  1   RI      214 non-null    float64
#  2   NA      214 non-null    float64
#  3   Mg      214 non-null    float64
#  4   Al      214 non-null    float64
#  5   Si      214 non-null    float64
#  6   K       214 non-null    float64
#  7   Ca      214 non-null    float64
#  8   Ba      214 non-null    float64
#  9   Fe      214 non-null    float64
#  10  Type    214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
#Checking the null values in our dataset.
glass_df.isnull().sum()
# Out:
# Id      0
# RI      0
# NA      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
#checking for any duplicate values .
glass_df.duplicated().sum()
# Out:
# 0

# %%
# returns the total number of unique values for each column.
glass_df.nunique().to_frame("Total No. of Unique Values in each column")
# Out:
#       Total No. of Unique Values in each column
# Id                                          214
# RI                                          178
# NA                                          142
# Mg                                           94
# Al                                          118
# Si                                          133
# K                                            65
# Ca                                          143
# Ba                                           34
# Fe                                           32
# Type                                          6

# %%
#checking the value count for each columns
for col in glass_df.columns:   
    print('-' * 20 + col + '-' * 20 , end=' - ')
    display(glass_df[col].value_counts())
# Out:
# --------------------Id-------------------- -
# 1      1
# 135    1
# 137    1
# 138    1
# 139    1
#       ..
# 75     1
# 76     1
# 77     1
# 78     1
# 214    1
# Name: Id, Length: 214, dtype: int64
# --------------------RI-------------------- -
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI, Length: 178, dtype: int64
# --------------------NA-------------------- -
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: NA, Length: 142, dtype: int64
# --------------------Mg-------------------- -
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg, Length: 94, dtype: int64
# --------------------Al-------------------- -
# 1.54    8
# 1.19    6
# 1.43    5
# ...

# %%
#Displaying Duplicate Values
glass_df.drop_duplicates(inplace=True)
glass_df.shape
# Out:
# (214, 11)

# %%
# Unique values present in target column
glass_df['Type'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7])

# %%
#Count of unique values in target column.
glass_df['Type'].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
# Getting statistical summary
glass_df.describe()
# Out:
#                Id          RI          NA          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     0.497056    8.956963    0.175047    0.057009    2.780374
# std      0.652192    1.423153    0.497219    0.097439    2.103739
# ...

# %%
# Removing the non significant data 'Id' from the dataset 
glass_df.drop('Id',axis=1,inplace=True)

# %%
glass_df
# Out:
#           RI     NA    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# # Data Visualisation

# %%
#Checking for null values using heatmap.
plt.figure(figsize=(10,5))
sns.heatmap(glass_df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Type', data=glass_df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
plt.figure(figsize=(15,20))
x = 1
for columns in glass_df:
    if x <= 11:
        ax= plt.subplot(5,2,x)
        sns.kdeplot(x= glass_df[columns], hue=glass_df['Type'],palette="flare",fill = True)
        plt.xlabel(columns)
        x+=1
plt.show()

# %%
plt.figure(figsize=(15,20))
x = 1

for columns in glass_df:
    if x <= 11:
        ax= plt.subplot(5,2,x)
        sns.distplot(glass_df[columns],color="green")
        plt.xlabel(columns)
        x+=1
plt.show()

# %%
sns.countplot(x='Type', data=glass_df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
plt.figure(figsize=(15,20))
x = 1
for columns in glass_df:
    if x <= 11:
        ax= plt.subplot(5,2,x)
        sns.scatterplot(glass_df[columns], color="seagreen")
        plt.xlabel(columns)
        x+=1
plt.show()

# %%
# rechecking the outliers 
plt.figure(figsize=(20,15),facecolor='lightblue')
x = 1
for col in glass_df :
    if x<=10:
        ax=plt.subplot(3,4,x)
        sns.boxplot(glass_df[col], color = 'r')
        plt.xlabel(col,fontsize=20)
    x +=1
plt.show()

# %%
sns.pairplot(glass_df)

# %%
glass_df.corr()
# Out:
#             RI        NA        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# NA   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# NA    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %%
plt.figure(figsize=(20,14))
sns.heatmap(glass_df.corr(), annot=True, fmt='0.2f', linewidths=0.20, cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
glass_df.corr()['Type'].sort_values(ascending = False)
# Out:
# Type    1.000000
# Al      0.598829
# Ba      0.575161
# NA      0.502898
# Si      0.151565
# Ca      0.000952
# K      -0.010054
# RI     -0.164237
# Fe     -0.188278
# Mg     -0.744993
# Name: Type, dtype: float64

# %%
plt.figure(figsize = (22,10))
glass_df.corr()['Type'].sort_values(ascending = False).drop(['Type']).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize = 15)
plt.ylabel('Target',fontsize = 15)
plt.title("Correlation between label and features using barplot",fontsize=20)
plt.show()

# %%
#checking the skewness.
plt.figure(figsize=(15,10))
x = 1 

for i in glass_df:
    if x <= 10:
        ax=plt.subplot(2,5,x)
        sns.histplot(glass_df[i], kde=True, bins=20)
        plt.xlabel(i, fontsize = 15)
    x += 1   
plt.show()

# %%
glass_df.skew()
# Out:
# RI      1.625431
# NA      0.454181
# Mg     -1.152559
# Al      0.907290
# Si     -0.730447
# K       6.551648
# Ca      2.047054
# Ba      3.416425
# Fe      1.754327
# Type    1.114915
# dtype: float64

# %%
# Removing Skewness using power transformer
from sklearn.preprocessing import PowerTransformer
col = ['Mg','Ca','Ba','Fe','K']   # removing only skewed data

pt = PowerTransformer(method='yeo-johnson')
glass_df[col] = pt.fit_transform(glass_df[col].values)

# %%
glass_df.skew()
# Out:
# RI      1.625431
# NA      0.454181
# Mg     -0.889528
# Al      0.907290
# Si     -0.730447
# K      -0.071816
# Ca     -0.209314
# Ba      1.824175
# Fe      0.858508
# Type    1.114915
# dtype: float64

# %%
#Importing the libary Zscore to remove skewness
from scipy.stats import zscore
z=np.abs(zscore(glass_df))
z.shape
# Out:
# (214, 10)

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([106, 106, 106, 107, 107, 107, 112, 163, 163, 163, 171, 171, 172,
#        172, 184, 184, 185, 186, 188, 201]), array([0, 1, 4, 0, 4, 6, 0, 3, 4, 6, 3, 5, 3, 5, 1, 4, 6, 6, 4, 4]))

# %%
df= glass_df[(z<3).all(axis=1)]

print("Old DataFrame ",glass_df.shape)
print("New DataFrame ",df.shape)
print("Total Drop Rows are ",glass_df.shape[0]-df.shape[0])
# Out:
# Old DataFrame  (214, 10)
# New DataFrame  (203, 10)
# Total Drop Rows are  11

# %%
Data_Loss = print("Data Loss Percentage :",((glass_df.shape[0]-df.shape[0])/glass_df.shape[0])*100)
# Out:
# Data Loss Percentage : 5.14018691588785

# %%
# Dividing the target variable("Type") into 2 different categories as mentioned :-
# 1=window glass (classes 1-4)
# 0=non window glass (classes 5-7)
df['Type'] = df['Type'].replace({1:1,2:1,3:1,4:1,5:0,6:0,7:0})
df['Type'].value_counts()
# Out:
# 1    160
# 0     43
# Name: Type, dtype: int64

# %%
x = df.drop(['Type'], axis=1)
y=df['Type']

# %%
x
# Out:
#           RI     NA        Mg    Al     Si         K        Ca        Ba  \
# 0    1.52101  13.64  1.876273  1.10  71.78 -1.289781 -0.010654 -0.454890
# 1    1.51761  13.89  0.668163  1.36  72.73  0.274843 -0.884532 -0.454890
# 2    1.51618  13.53  0.608046  1.54  72.99  0.018565 -0.938251 -0.454890
# 3    1.51766  13.21  0.778426  1.29  72.61  0.501963 -0.488967 -0.454890
# 4    1.51742  13.27  0.692438  1.24  73.08  0.453753 -0.636365 -0.454890
# ..       ...    ...       ...   ...    ...       ...       ...       ...
# 209  1.51623  14.14 -1.739289  2.88  72.61 -1.187926  0.334634  2.371029
# 210  1.51685  14.92 -1.739289  1.99  73.06 -1.619585 -0.319385  2.376703
# 211  1.52065  14.36 -1.739289  2.02  73.42 -1.619585 -0.282733  2.376848
# 212  1.51651  14.38 -1.739289  1.94  73.61 -1.619585 -0.246446  2.376638
# 213  1.51711  14.23 -1.739289  2.08  73.36 -1.619585 -0.122236  2.376923
#
#            Fe
# 0   -0.680015
# 1   -0.680015
# 2   -0.680015
# 3   -0.680015
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    0
# 210    0
# 211    0
# 212    0
# 213    0
# Name: Type, Length: 203, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
x_scaled=pd.DataFrame(scaler.fit_transform(x),columns = x.columns)
x_scaled
# Out:
#            RI        NA        Mg        Al        Si         K        Ca  \
# 0    1.076924  0.316067  1.868276 -0.720041 -1.527242 -1.364421 -0.070517
# 1   -0.276659  0.653476  0.623768 -0.135008  0.039483  0.378146 -1.182293
# 2   -0.845960  0.167608  0.561839  0.270015  0.468271  0.092722 -1.250636
# 3   -0.256753 -0.264276  0.737352 -0.292517 -0.158419  0.631096 -0.679042
# 4   -0.352300 -0.183298  0.648774 -0.405023  0.616697  0.577403 -0.866567
# ..        ...       ...       ...       ...       ...       ...       ...
# 198 -0.826054  0.990886 -1.856217  3.285187 -0.158419 -1.250982  0.368770
# 199 -0.579225  2.043602 -1.856217  1.282573  0.583714 -1.731734 -0.463294
# 200  0.933604  1.287805 -1.856217  1.350077  1.177420 -1.731734 -0.416665
# 201 -0.714583  1.314798 -1.856217  1.170067  1.490765 -1.731734 -0.370499
# 202 -0.475715  1.112353 -1.856217  1.485085  1.078469 -1.731734 -0.212475
#
#            Ba        Fe
# 0   -0.438277 -0.691704
# 1   -0.438277 -0.691704
# ...

# %%
#Checking Variance Inflation Factor

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x_scaled.values,i) for i in range(len(x_scaled.columns))]
vif['Features'] = x.columns

vif
# Out:
#    VIF values Features
# 0    6.089562       RI
# 1    6.938005       NA
# 2   11.120019       Mg
# 3    4.347238       Al
# 4    6.295441       Si
# 5    4.330280        K
# 6    8.854068       Ca
# 7    3.034571       Ba
# 8    1.074405       Fe

# %%
x_scaled = x_scaled.drop(['Mg'], axis=1)
x= x_scaled

# %%
#Checking Variance Inflation Factor

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#    VIF values Features
# 0    5.367724       RI
# 1    3.689825       NA
# 2    2.415781       Al
# 3    2.770609       Si
# 4    3.480432        K
# 5    3.668296       Ca
# 6    2.647884       Ba
# 7    1.066104       Fe

# %%
from imblearn.over_sampling import SMOTE
smt= SMOTE()
x_smote,y_smote=smt.fit_resample(x_scaled,y)
y_smote.value_counts()
# Out:
# 1    160
# 0    160
# Name: Type, dtype: int64

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
Model= [LogisticRegression(),RandomForestClassifier(),DecisionTreeClassifier(), SVC(),ExtraTreesClassifier(),  GradientBoostingClassifier()]

# %%
for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x_smote,y_smote,test_size = .20, random_state=i)
    for m in Model:
        maxAcc = 0
        maxRs = 0
        m.fit(x_train,y_train)
        m.score(x_train,y_train)
        pred = m.predict(x_test)
        acc = accuracy_score(y_test,pred)
        if acc>maxAcc:
            maxAcc = acc
            maxRs=i
print("For Model",mod,"Best Accuracy is:", maxAcc, "on Random State:", maxRs)
# Out:
# For Model GradientBoostingClassifier() Best Accuracy is: 0.921875 on Random State: 49

# %%
x_train,x_test,y_train,y_test = train_test_split(x_smote,y_smote,test_size = .20, random_state=49)

# %%
#Splitting the data into training and testing Data.
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (256, 8)
# (64, 8)
# (256,)
# (64,)

# %%
from sklearn.model_selection import cross_val_score
for m in Model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predmt = m.predict(x_train)
    predm=m.predict(x_test)
    print(m)
    print(f" Accuracy score for training data: {accuracy_score(y_train,predmt)*100:.2f}")
    print(f" Accuracy score for testing data: {accuracy_score(y_test,predm)*100:.2f}")
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,predm))
    print ('\n','Classification Report:','\n',classification_report(y_test,predm))
    score = cross_val_score(m,x,y,cv=5)
    print('\n',f"Cross val score: {score.mean()*100:.2f}%")
    print(f'\n Difference between accuracy score and cross val score {(accuracy_score(y_test,predm)-score.mean())*100:.2f}')
    print('\n')
# Out:
# LogisticRegression()
#  Accuracy score for training data: 97.27
#  Accuracy score for testing data: 98.44
#
#  Confusion matrix:
#  [[35  0]
#  [ 1 28]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        35
#            1       1.00      0.97      0.98        29
#
#     accuracy                           0.98        64
#    macro avg       0.99      0.98      0.98        64
# weighted avg       0.98      0.98      0.98        64
#
#
#  Cross val score: 87.72%
#
#  Difference between accuracy score and cross val score 10.72
#
#
# RandomForestClassifier()
#  Accuracy score for training data: 100.00
#  Accuracy score for testing data: 93.75
#
#  Confusion matrix:
#  [[34  1]
#  [ 3 26]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94        35
#            1       0.96      0.90      0.93        29
#
# ...

# %% [markdown]
# GradientBoostingClassifier is the best model

# %%
parameters={"criterion": ["friedman_mse",  "squared_error"],
            "loss":["log_loss","deviance","exponential"],
            "max_features":["log2","sqrt","None"],
            'learning_rate': [0.01,0.05,0.1,1,0.5], 
            'max_depth': [3,4,5],
            'n_estimators': [5,10,15,20,100],
            }
GCV=GridSearchCV(GradientBoostingClassifier(),parameters,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'learning_rate': [0.01, 0.05, 0.1, 1, 0.5],
#                          'loss': ['log_loss', 'deviance', 'exponential'],
#                          'max_depth': [3, 4, 5],
#                          'max_features': ['log2', 'sqrt', 'None'],
#                          'n_estimators': [5, 10, 15, 20, 100]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'learning_rate': 0.5,
#  'loss': 'exponential',
#  'max_depth': 4,
#  'max_features': 'log2',
#  'n_estimators': 15}

# %%
GCV.best_score_
# Out:
# 0.9766214177978885

# %%
Final_model=GradientBoostingClassifier(criterion='friedman_mse', loss='exponential', learning_rate=0.5, max_depth=4, max_features = 'log2', n_estimators=15)
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 93.75

# %%
# Let's plot the confusion matrix
mat = confusion_matrix(y_test,pred)
plt.subplots(figsize=(12,8))
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=True)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(248.7222222222224, 0.5, 'predicted label')

# %%
from sklearn.metrics import roc_curve,auc,roc_auc_score,plot_roc_curve
pred_test=Final_model.predict(x_test)
fpr,tpr,threshold=roc_curve(pred_test,y_test)
roc_auc=auc(fpr,tpr)
plt.figure()
plt.plot(fpr,tpr,color='blue',lw=10,label='ROC Curve (area=%0.2f)' % roc_auc)
plt.plot([0,1],[0,1],color='red',lw=10,linestyle='--')

plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate ')
plt.ylabel('True Positive Rate ')
plt.title("Reciever Operating Characterstics ")
plt.legend(loc='lower right')
plt.show()

# %%
import pickle
filename='GlassIdentification.pkl'
pickle.dump(Final_model,open(filename,'wb'))

# %%
model=pickle.load(open("GlassIdentification.pkl","rb"))
prediction=model.predict(x_test)
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"]).T
# Out:
#     Predicted  Original
# 0           0         0
# 1           0         0
# 2           1         1
# 3           1         1
# 4           0         0
# ..        ...       ...
# 59          0         0
# 60          1         1
# 61          0         0
# 62          0         0
# 63          1         1
#
# [64 rows x 2 columns]
